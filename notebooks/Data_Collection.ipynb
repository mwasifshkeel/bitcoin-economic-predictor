# %%
import requests
import pandas as pd
import datetime
import time
import csv

def fetch_all_btc_data():
    """
    Fetch all available BTC/USDT historical data from Binance API at 1-hour intervals
    and save to CSV file in the specified format.
    """
    # Base URL for Binance API
    base_url = "https://api.binance.com/api/v3/klines"

    # Symbol and interval
    symbol = "BTCUSDT"
    interval = "1h"

    # CSV file name
    csv_filename = "btc_historical_data.csv"

    # Initialize data collection
    all_data = []
    start_time = None

    print("Starting to fetch BTC historical data from Binance...")

    # First API call to get the most recent data
    params = {
        "symbol": symbol,
        "interval": interval,
        "limit": 1000  # Maximum allowed by Binance
    }

    try:
        response = requests.get(base_url, params=params)
        response.raise_for_status()  # Raise an exception for HTTP errors

        data = response.json()
        if not data:
            print("No data returned from Binance API.")
            return

        # Process and store this batch of data
        for candle in data:
            timestamp = int(candle[0])
            dt_object = datetime.datetime.fromtimestamp(timestamp / 1000)
            formatted_date = dt_object.strftime("%d-%m-%y %H:%M")

            open_price = float(candle[1])
            close_price = float(candle[4])
            high_price = float(candle[2])
            low_price = float(candle[3])
            volume = float(candle[5])

            all_data.append({
                "Date Time": formatted_date,
                "Crypto": "Bitcoin",
                "Open Price": f"{open_price:.0f}",
                "Close Price": f"{close_price:.0f}",
                "High Price": f"{high_price:.0f}",
                "Low Price": f"{low_price:.0f}",
                "Volume": f"{volume:.2f} BTC"
            })

        # Set the start time for the next batch (oldest entry from current batch)
        start_time = int(data[0][0])

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return

    # Number of successful API calls
    api_call_count = 1

    # Continue fetching older data until we reach the beginning or an error occurs
    while True:
        # Add a delay to avoid rate limiting
        time.sleep(0.5)

        # Update parameters to get the next batch of older data
        params = {
            "symbol": symbol,
            "interval": interval,
            "endTime": start_time - 1,  # Get data older than the oldest entry we have
            "limit": 1000
        }

        try:
            response = requests.get(base_url, params=params)
            response.raise_for_status()

            data = response.json()

            # If no more data is returned, we've reached the beginning
            if not data:
                print("Reached the beginning of available data.")
                break

            # Process and store this batch of data
            for candle in data:
                timestamp = int(candle[0])
                dt_object = datetime.datetime.fromtimestamp(timestamp / 1000)
                formatted_date = dt_object.strftime("%d-%m-%y %H:%M")

                open_price = float(candle[1])
                close_price = float(candle[4])
                high_price = float(candle[2])
                low_price = float(candle[3])
                volume = float(candle[5])

                all_data.append({
                    "Date Time": formatted_date,
                    "Crypto": "Bitcoin",
                    "Open Price": f"{open_price:.0f}",
                    "Close Price": f"{close_price:.0f}",
                    "High Price": f"{high_price:.0f}",
                    "Low Price": f"{low_price:.0f}",
                    "Volume": f"{volume:.2f} BTC"
                })

            # Update the start time for the next batch
            start_time = int(data[0][0])

            # Print progress
            api_call_count += 1
            if api_call_count % 10 == 0:
                oldest_date = datetime.datetime.fromtimestamp(start_time / 1000).strftime("%d-%m-%Y %H:%M")
                print(f"Progress: Downloaded {len(all_data)} records, oldest data point: {oldest_date}")

        except requests.exceptions.RequestException as e:
            print(f"Error fetching data: {e}")
            break

    # Sort data by date (oldest to newest)
    all_data.sort(key=lambda x: datetime.datetime.strptime(x["Date Time"], "%d-%m-%y %H:%M"))

    # Write to CSV
    try:
        with open(csv_filename, "w", newline="") as csvfile:
            fieldnames = ["Date Time", "Crypto", "Open Price", "Close Price", "High Price", "Low Price", "Volume"]
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

            writer.writeheader()
            for row in all_data:
                writer.writerow(row)

        print(f"Successfully downloaded {len(all_data)} records of BTC historical data.")
        print(f"Data saved to {csv_filename}")
        print(f"Date range: {all_data[0]['Date Time']} to {all_data[-1]['Date Time']}")

    except IOError as e:
        print(f"Error writing to CSV: {e}")

if __name__ == "__main__":
    fetch_all_btc_data()
# Out:
# Starting to fetch BTC historical data from Binance...
# Progress: Downloaded 10000 records, oldest data point: 12-03-2024 21:00
# Progress: Downloaded 20000 records, oldest data point: 21-01-2023 04:00
# Progress: Downloaded 30000 records, oldest data point: 30-11-2021 12:00
# Progress: Downloaded 40000 records, oldest data point: 09-10-2020 01:00
# Progress: Downloaded 50000 records, oldest data point: 18-08-2019 17:00
# Progress: Downloaded 60000 records, oldest data point: 25-06-2018 21:00
# Reached the beginning of available data.
# Successfully downloaded 67465 records of BTC historical data.
# Data saved to btc_historical_data.csv
# Date range: 17-08-17 04:00 to 03-05-25 12:00

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import pandas as pd
import time
import concurrent.futures
from datetime import datetime, timedelta
import os

def generate_dates(start_date_str="2017-04-20", end_date_str="2019-11-11"):
    """Generate a list of dates from the start date to the end date."""
    start_date = datetime.strptime(start_date_str, "%Y-%m-%d")
    end_date = datetime.strptime(end_date_str, "%Y-%m-%d")

    dates = []
    current = start_date
    while current <= end_date:
        # Format for forexfactory URL: lowercase month abbreviation + day + year
        formatted_date = current.strftime("%b%d.%Y").lower()
        dates.append(formatted_date)
        current += timedelta(days=1)

    return dates

def scrape_forex_factory(date_str):
    """Scrape data for a specific date from ForexFactory."""
    url = f"https://www.forexfactory.com/calendar?day={date_str}"
    print(f"Scraping: {url}")

    # Set up headless Chrome
    options = Options()
    options.add_argument("--headless")
    options.add_argument("--disable-gpu")
    options.add_argument("--no-sandbox")
    options.add_argument("start-maximized")
    options.add_argument("window-size=1920,1080")
    options.add_argument("user-agent=Mozilla/5.0")

    driver = webdriver.Chrome(options=options)
    driver.get(url)

    # Wait for JavaScript to load content
    time.sleep(5)

    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    data = []
    current_date = None

    rows = soup.select("tr.calendar__row")

    for row in rows:
        if "calendar__row--day-breaker" in row.get("class", []):
            date_span = row.select_one("td.calendar__cell span")
            if date_span:
                current_date = date_span.text.strip()
            continue

        time_td = row.select_one("td.calendar__time span")
        if not time_td:
            continue

        time_val = time_td.text.strip()
        currency = row.select_one("td.calendar__currency span")
        currency = currency.text.strip() if currency else ""

        impact_span = row.select_one("td.calendar__impact span[title]")
        impact = impact_span["title"].replace(" Impact Expected", "") if impact_span else ""

        event_title = row.select_one("td.calendar__event span.calendar__event-title")
        event_title = event_title.text.strip() if event_title else ""

        actual = row.select_one("td.calendar__actual span")
        actual = actual.text.strip() if actual else ""

        forecast = row.select_one("td.calendar__forecast span")
        forecast = forecast.text.strip() if forecast else ""

        previous = row.select_one("td.calendar__previous span")
        previous = previous.text.strip() if previous else ""

        data.append({
            "Date": current_date,
            "Time": time_val,
            "Currency": currency,
            "Impact": impact,
            "Event Title": event_title,
            "Actual": actual,
            "Forecast": forecast,
            "Previous": previous
        })

    driver.quit()

    return data

def main():
    # Generate all dates to scrape
    dates = generate_dates()
    all_data = []

    # Define output path
    output_path = "forexfactory_calendar_full.csv"
    temp_output_path = "temp_" + output_path

    # Create a counter for completed dates
    completed_dates = 0

    # Use ThreadPoolExecutor to run multiple scrapers concurrently
    with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
        # Submit scraping tasks
        future_to_date = {executor.submit(scrape_forex_factory, date): date for date in dates}

        # Process results as they complete
        for future in concurrent.futures.as_completed(future_to_date):
            date = future_to_date[future]
            try:
                data = future.result()
                if data:
                    all_data.extend(data)
                    completed_dates += 1
                    print(f"Completed scraping for {date}, got {len(data)} entries")

                    # Save data after every completed date
                    temp_df = pd.DataFrame(all_data)
                    temp_df.to_csv(temp_output_path, index=False)
                    print(f"Saved {len(all_data)} entries to temporary file after {completed_dates} dates")

                    # Create more frequent backups - every 5 dates instead of 10
                    if completed_dates % 5 == 0:
                        backup_path = f"backup_{completed_dates}_{output_path}"
                        temp_df.to_csv(backup_path, index=False)
                        print(f"Created backup at {backup_path}")

                    # Also create time-based backups every hour
                    current_hour = datetime.now().strftime("%Y%m%d_%H")
                    hourly_backup_path = f"hourly_backup_{current_hour}_{output_path}"
                    if not os.path.exists(hourly_backup_path):
                        temp_df.to_csv(hourly_backup_path, index=False)
                        print(f"Created hourly backup at {hourly_backup_path}")

            except Exception as exc:
                # Save data even when an exception occurs
                if all_data:
                    error_backup_path = f"error_backup_{datetime.now().strftime('%Y%m%d_%H%M%S')}_{output_path}"
                    pd.DataFrame(all_data).to_csv(error_backup_path, index=False)
                    print(f"Error occurred. Created emergency backup at {error_backup_path}")
                print(f"Error scraping {date}: {exc}")

    # Convert results to DataFrame and save final output
    df = pd.DataFrame(all_data)
    df.to_csv(output_path, index=False)
    print(f"Scraping complete. Saved {len(df)} entries to {output_path}")

    print(f"Temporary file {temp_output_path} kept as additional backup")

if __name__ == "__main__":
    main()
# Out:
# Scraping: https://www.forexfactory.com/calendar?day=apr20.2017Scraping: https://www.forexfactory.com/calendar?day=apr21.2017
#
# Scraping: https://www.forexfactory.com/calendar?day=apr22.2017
# Scraping: https://www.forexfactory.com/calendar?day=apr23.2017
# Scraping: https://www.forexfactory.com/calendar?day=apr24.2017
# Scraping: https://www.forexfactory.com/calendar?day=apr25.2017
# Scraping: https://www.forexfactory.com/calendar?day=apr26.2017
# Scraping: https://www.forexfactory.com/calendar?day=apr27.2017
# Scraping: https://www.forexfactory.com/calendar?day=apr28.2017
# Scraping: https://www.forexfactory.com/calendar?day=apr29.2017
# Scraping: https://www.forexfactory.com/calendar?day=apr30.2017
# Completed scraping for apr29.2017, got 1 entries
# Saved 1 entries to temporary file after 1 dates
# Created hourly backup at hourly_backup_20250503_19_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=may01.2017
# Completed scraping for apr22.2017, got 2 entries
# Saved 3 entries to temporary file after 2 dates
# Scraping: https://www.forexfactory.com/calendar?day=may02.2017
# Completed scraping for apr25.2017, got 10 entries
# Saved 13 entries to temporary file after 3 dates
# Scraping: https://www.forexfactory.com/calendar?day=may03.2017
# Completed scraping for apr23.2017, got 3 entries
# Saved 16 entries to temporary file after 4 dates
# Scraping: https://www.forexfactory.com/calendar?day=may04.2017
# Completed scraping for apr20.2017, got 9 entries
# Saved 25 entries to temporary file after 5 dates
# Created backup at backup_5_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=may05.2017
# Completed scraping for apr21.2017, got 12 entries
# Saved 37 entries to temporary file after 6 dates
# Scraping: https://www.forexfactory.com/calendar?day=may06.2017
# Completed scraping for apr28.2017, got 14 entries
# Scraping: https://www.forexfactory.com/calendar?day=may07.2017
# Saved 51 entries to temporary file after 7 dates
# Completed scraping for apr26.2017, got 7 entries
# Saved 58 entries to temporary file after 8 dates
# Scraping: https://www.forexfactory.com/calendar?day=may08.2017
# Completed scraping for apr27.2017, got 17 entries
# Saved 75 entries to temporary file after 9 dates
# Scraping: https://www.forexfactory.com/calendar?day=may09.2017
# Completed scraping for apr24.2017, got 9 entries
# Saved 84 entries to temporary file after 10 dates
# Created backup at backup_10_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=may10.2017
# Completed scraping for may07.2017, got 4 entries
# Saved 88 entries to temporary file after 11 dates
# Scraping: https://www.forexfactory.com/calendar?day=may11.2017Completed scraping for apr30.2017, got 4 entries
#
# Saved 92 entries to temporary file after 12 dates
# Scraping: https://www.forexfactory.com/calendar?day=may12.2017Completed scraping for may05.2017, got 7 entries
#
# Saved 99 entries to temporary file after 13 dates
# Scraping: https://www.forexfactory.com/calendar?day=may13.2017
# Scraping: https://www.forexfactory.com/calendar?day=may14.2017Completed scraping for may01.2017, got 14 entries
#
# Scraping: https://www.forexfactory.com/calendar?day=may15.2017
# Saved 113 entries to temporary file after 14 dates
# Completed scraping for may03.2017, got 15 entries
# Saved 128 entries to temporary file after 15 dates
# Created backup at backup_15_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=may16.2017
# Completed scraping for may08.2017, got 12 entries
# Saved 140 entries to temporary file after 16 dates
# Scraping: https://www.forexfactory.com/calendar?day=may17.2017
# Completed scraping for may02.2017, got 18 entries
# Saved 158 entries to temporary file after 17 dates
# Scraping: https://www.forexfactory.com/calendar?day=may18.2017
# Completed scraping for may04.2017, got 21 entries
# Saved 179 entries to temporary file after 18 dates
# Scraping: https://www.forexfactory.com/calendar?day=may19.2017
# Completed scraping for may09.2017, got 12 entries
# Saved 191 entries to temporary file after 19 dates
# Scraping: https://www.forexfactory.com/calendar?day=may20.2017Completed scraping for may13.2017, got 1 entries
#
# Saved 192 entries to temporary file after 20 dates
# Created backup at backup_20_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=may21.2017
# Completed scraping for may14.2017, got 6 entries
# Saved 198 entries to temporary file after 21 dates
# Scraping: https://www.forexfactory.com/calendar?day=may22.2017
# Completed scraping for may16.2017, got 15 entries
# Saved 213 entries to temporary file after 22 dates
# Scraping: https://www.forexfactory.com/calendar?day=may23.2017
# Completed scraping for may10.2017, got 15 entries
# Saved 228 entries to temporary file after 23 dates
# Scraping: https://www.forexfactory.com/calendar?day=may24.2017
# Completed scraping for may12.2017, got 9 entries
# Saved 237 entries to temporary file after 24 dates
# Scraping: https://www.forexfactory.com/calendar?day=may25.2017
# Completed scraping for may11.2017, got 14 entries
# Saved 251 entries to temporary file after 25 dates
# Created backup at backup_25_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=may26.2017Completed scraping for may17.2017, got 10 entries
#
# Saved 261 entries to temporary file after 26 dates
# Scraping: https://www.forexfactory.com/calendar?day=may27.2017
# Completed scraping for may19.2017, got 5 entries
# Saved 266 entries to temporary file after 27 dates
# Scraping: https://www.forexfactory.com/calendar?day=may28.2017
# Completed scraping for may18.2017, got 10 entries
# Saved 276 entries to temporary file after 28 dates
# Scraping: https://www.forexfactory.com/calendar?day=may29.2017
# Error occurred. Created emergency backup at error_backup_20250503_192912_forexfactory_calendar_full.csv
# Error scraping may15.2017: HTTPConnectionPool(host='localhost', port=41539): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=may30.2017
# Scraping: https://www.forexfactory.com/calendar?day=may31.2017Completed scraping for may21.2017, got 2 entries
# Saved 278 entries to temporary file after 29 dates
#
# Scraping: https://www.forexfactory.com/calendar?day=jun01.2017Completed scraping for may22.2017, got 11 entries
#
# Saved 289 entries to temporary file after 30 dates
# Created backup at backup_30_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=jun02.2017
# Completed scraping for may27.2017, got 1 entries
# Saved 290 entries to temporary file after 31 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun03.2017
# Completed scraping for may23.2017, got 18 entries
# Saved 308 entries to temporary file after 32 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun04.2017
# Completed scraping for may24.2017, got 12 entries
# Saved 320 entries to temporary file after 33 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun05.2017
# Completed scraping for may25.2017, got 12 entries
# Saved 332 entries to temporary file after 34 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun06.2017
# Completed scraping for may28.2017, got 1 entries
# Saved 333 entries to temporary file after 35 dates
# Created backup at backup_35_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=jun07.2017
# Completed scraping for may26.2017, got 3 entries
# Saved 336 entries to temporary file after 36 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun08.2017
# Completed scraping for may29.2017, got 9 entries
# Saved 345 entries to temporary file after 37 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun09.2017
# Completed scraping for jun04.2017, got 5 entries
# Saved 350 entries to temporary file after 38 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun10.2017
# Completed scraping for may31.2017, got 20 entries
# Saved 370 entries to temporary file after 39 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun11.2017Completed scraping for jun02.2017, got 6 entries
#
# Saved 376 entries to temporary file after 40 dates
# Created backup at backup_40_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=jun12.2017
# Completed scraping for jun05.2017, got 17 entries
# Saved 393 entries to temporary file after 41 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun13.2017
# Completed scraping for jun01.2017, got 25 entries
# Saved 418 entries to temporary file after 42 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun14.2017
# Completed scraping for may30.2017, got 16 entries
# Saved 434 entries to temporary file after 43 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun15.2017
# Scraping: https://www.forexfactory.com/calendar?day=jun16.2017
# Completed scraping for jun07.2017, got 13 entries
# Saved 447 entries to temporary file after 44 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun17.2017
# Completed scraping for jun06.2017, got 11 entries
# Saved 458 entries to temporary file after 45 dates
# Created backup at backup_45_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=jun18.2017
# Completed scraping for jun08.2017, got 15 entries
# Saved 473 entries to temporary file after 46 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun19.2017
# Scraping: https://www.forexfactory.com/calendar?day=jun20.2017
# Completed scraping for jun12.2017, got 8 entries
# Saved 481 entries to temporary file after 47 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun21.2017
# Completed scraping for jun11.2017, got 3 entries
# Saved 484 entries to temporary file after 48 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun22.2017
# Scraping: https://www.forexfactory.com/calendar?day=jun23.2017
# Completed scraping for jun09.2017, got 8 entries
# Saved 492 entries to temporary file after 49 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun24.2017
# Completed scraping for jun13.2017, got 11 entries
# Saved 503 entries to temporary file after 50 dates
# Created backup at backup_50_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=jun25.2017
# Completed scraping for jun14.2017, got 15 entries
# Saved 518 entries to temporary file after 51 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun26.2017
# Completed scraping for jun18.2017, got 6 entries
# Saved 524 entries to temporary file after 52 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun27.2017
# Completed scraping for jun16.2017, got 8 entries
# Saved 532 entries to temporary file after 53 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun28.2017
# Completed scraping for jun15.2017, got 19 entries
# Saved 551 entries to temporary file after 54 dates
# Scraping: https://www.forexfactory.com/calendar?day=jun29.2017Completed scraping for jun19.2017, got 6 entries
#
# Saved 557 entries to temporary file after 55 dates
# Created backup at backup_55_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=jun30.2017
# Scraping: https://www.forexfactory.com/calendar?day=jul01.2017
# Completed scraping for jun21.2017, got 10 entries
# Saved 567 entries to temporary file after 56 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul02.2017
# Completed scraping for jun26.2017, got 6 entries
# Saved 573 entries to temporary file after 57 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul03.2017
# Completed scraping for jun22.2017, got 13 entries
# Saved 586 entries to temporary file after 58 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul04.2017
# Completed scraping for jun20.2017, got 14 entries
# Saved 600 entries to temporary file after 59 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul05.2017Completed scraping for jun25.2017, got 1 entries
#
# Saved 601 entries to temporary file after 60 dates
# Created backup at backup_60_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=jul06.2017
# Completed scraping for jun23.2017, got 8 entries
# Saved 609 entries to temporary file after 61 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul07.2017
# Completed scraping for jun27.2017, got 12 entries
# Saved 621 entries to temporary file after 62 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul08.2017
# Completed scraping for jun28.2017, got 11 entries
# Saved 632 entries to temporary file after 63 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul09.2017Completed scraping for jun29.2017, got 13 entries
#
# Saved 645 entries to temporary file after 64 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul10.2017
# Completed scraping for jul01.2017, got 1 entries
# Saved 646 entries to temporary file after 65 dates
# Created backup at backup_65_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=jul11.2017
# Completed scraping for jul02.2017, got 7 entries
# Saved 653 entries to temporary file after 66 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul12.2017
# Completed scraping for jun30.2017, got 12 entries
# Saved 665 entries to temporary file after 67 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul13.2017Completed scraping for jul04.2017, got 12 entries
#
# Saved 677 entries to temporary file after 68 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul14.2017
# Completed scraping for jul05.2017, got 13 entries
# Saved 690 entries to temporary file after 69 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul15.2017
# Completed scraping for jul03.2017, got 20 entries
# Saved 710 entries to temporary file after 70 dates
# Created backup at backup_70_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=jul16.2017
# Completed scraping for jul07.2017, got 15 entries
# Saved 725 entries to temporary file after 71 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul17.2017
# Completed scraping for jul06.2017, got 14 entries
# Saved 739 entries to temporary file after 72 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul18.2017Completed scraping for jul08.2017, got 2 entries
#
# Saved 741 entries to temporary file after 73 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul19.2017
# Completed scraping for jul09.2017, got 2 entries
# Saved 743 entries to temporary file after 74 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul20.2017
# Completed scraping for jul11.2017, got 13 entries
# Saved 756 entries to temporary file after 75 dates
# Created backup at backup_75_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=jul21.2017
# Completed scraping for jul10.2017, got 9 entries
# Saved 765 entries to temporary file after 76 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul22.2017
# Completed scraping for jul12.2017, got 17 entries
# Saved 782 entries to temporary file after 77 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul23.2017
# Scraping: https://www.forexfactory.com/calendar?day=jul24.2017
# Completed scraping for jul13.2017, got 11 entries
# Saved 793 entries to temporary file after 78 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul25.2017
# Completed scraping for jul14.2017, got 7 entries
# Saved 800 entries to temporary file after 79 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul26.2017
# Completed scraping for jul16.2017, got 4 entries
# Saved 804 entries to temporary file after 80 dates
# Created backup at backup_80_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=jul27.2017
# Completed scraping for jul17.2017, got 4 entries
# Saved 808 entries to temporary file after 81 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul28.2017
# Completed scraping for jul18.2017, got 9 entries
# Saved 817 entries to temporary file after 82 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul29.2017
# Completed scraping for jul19.2017, got 6 entries
# Saved 823 entries to temporary file after 83 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul30.2017
# Completed scraping for jul20.2017, got 13 entries
# Saved 836 entries to temporary file after 84 dates
# Scraping: https://www.forexfactory.com/calendar?day=jul31.2017
# Scraping: https://www.forexfactory.com/calendar?day=aug01.2017
# Completed scraping for jul21.2017, got 3 entries
# Saved 839 entries to temporary file after 85 dates
# Created backup at backup_85_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=aug02.2017
# Completed scraping for jul23.2017, got 1 entries
# Saved 840 entries to temporary file after 86 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug03.2017
# Completed scraping for jul24.2017, got 10 entries
# Saved 850 entries to temporary file after 87 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug04.2017
# Completed scraping for jul26.2017, got 7 entries
# Saved 857 entries to temporary file after 88 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug05.2017
# Completed scraping for jul27.2017, got 10 entries
# Saved 867 entries to temporary file after 89 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug06.2017
# Completed scraping for jul25.2017, got 15 entries
# Saved 882 entries to temporary file after 90 dates
# Created backup at backup_90_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=aug07.2017
# Completed scraping for jul28.2017, got 8 entries
# Saved 890 entries to temporary file after 91 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug08.2017
# Scraping: https://www.forexfactory.com/calendar?day=aug09.2017
# Completed scraping for jul30.2017, got 4 entries
# Saved 894 entries to temporary file after 92 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug10.2017
# Completed scraping for jul31.2017, got 13 entries
# Saved 907 entries to temporary file after 93 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug11.2017Completed scraping for aug01.2017, got 25 entries
#
# Saved 932 entries to temporary file after 94 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug12.2017
# Completed scraping for aug02.2017, got 14 entries
# Saved 946 entries to temporary file after 95 dates
# Created backup at backup_95_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=aug13.2017
# Scraping: https://www.forexfactory.com/calendar?day=aug14.2017
# Completed scraping for aug04.2017, got 5 entries
# Saved 951 entries to temporary file after 96 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug15.2017
# Completed scraping for aug03.2017, got 17 entries
# Saved 968 entries to temporary file after 97 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug16.2017
# Completed scraping for aug07.2017, got 15 entries
# Saved 983 entries to temporary file after 98 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug17.2017
# Completed scraping for aug06.2017, got 4 entries
# Saved 987 entries to temporary file after 99 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug18.2017
# Completed scraping for aug08.2017, got 12 entries
# Saved 999 entries to temporary file after 100 dates
# Created backup at backup_100_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=aug19.2017
# Completed scraping for aug09.2017, got 13 entries
# Saved 1012 entries to temporary file after 101 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug20.2017
# Completed scraping for aug10.2017, got 14 entries
# Saved 1026 entries to temporary file after 102 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug21.2017Completed scraping for aug11.2017, got 5 entries
#
# Saved 1031 entries to temporary file after 103 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug22.2017
# Scraping: https://www.forexfactory.com/calendar?day=aug23.2017
# Completed scraping for aug13.2017, got 5 entries
# Saved 1036 entries to temporary file after 104 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug24.2017
# Completed scraping for aug15.2017, got 15 entries
# Saved 1051 entries to temporary file after 105 dates
# Created backup at backup_105_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=aug25.2017
# Completed scraping for aug14.2017, got 2 entries
# Saved 1053 entries to temporary file after 106 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug26.2017
# Completed scraping for aug17.2017, got 9 entries
# Saved 1062 entries to temporary file after 107 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug27.2017
# Completed scraping for aug16.2017, got 9 entries
# Saved 1071 entries to temporary file after 108 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug28.2017
# Completed scraping for aug18.2017, got 5 entries
# Saved 1076 entries to temporary file after 109 dates
# Scraping: https://www.forexfactory.com/calendar?day=aug29.2017
# Scraping: https://www.forexfactory.com/calendar?day=aug30.2017
# Completed scraping for aug20.2017, got 3 entries
# Saved 1079 entries to temporary file after 110 dates
# Created backup at backup_110_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=aug31.2017
# Completed scraping for aug21.2017, got 4 entries
# Saved 1083 entries to temporary file after 111 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep01.2017
# Scraping: https://www.forexfactory.com/calendar?day=sep02.2017
# Completed scraping for aug22.2017, got 9 entries
# Saved 1092 entries to temporary file after 112 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep03.2017
# Completed scraping for aug23.2017, got 11 entries
# Saved 1103 entries to temporary file after 113 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep04.2017
# Completed scraping for aug25.2017, got 6 entries
# Saved 1109 entries to temporary file after 114 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep05.2017
# Completed scraping for aug26.2017, got 1 entries
# Saved 1110 entries to temporary file after 115 dates
# Created backup at backup_115_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=sep06.2017
# Completed scraping for aug24.2017, got 11 entries
# Saved 1121 entries to temporary file after 116 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep07.2017
# Completed scraping for aug28.2017, got 5 entries
# Saved 1126 entries to temporary file after 117 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep08.2017Completed scraping for aug29.2017, got 11 entries
#
# Saved 1137 entries to temporary file after 118 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep09.2017
# Completed scraping for aug30.2017, got 16 entries
# Saved 1153 entries to temporary file after 119 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep10.2017
# Completed scraping for sep03.2017, got 4 entries
# Saved 1157 entries to temporary file after 120 dates
# Created backup at backup_120_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=sep11.2017
# Scraping: https://www.forexfactory.com/calendar?day=sep12.2017
# Completed scraping for sep04.2017, got 12 entries
# Saved 1169 entries to temporary file after 121 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep13.2017
# Completed scraping for aug31.2017, got 17 entries
# Saved 1186 entries to temporary file after 122 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep14.2017
# Completed scraping for sep06.2017, got 11 entries
# Saved 1197 entries to temporary file after 123 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep15.2017
# Completed scraping for sep05.2017, got 18 entries
# Saved 1215 entries to temporary file after 124 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep16.2017
# Completed scraping for sep01.2017, got 15 entries
# Saved 1230 entries to temporary file after 125 dates
# Created backup at backup_125_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=sep17.2017Completed scraping for sep07.2017, got 21 entries
#
# Saved 1251 entries to temporary file after 126 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep18.2017
# Scraping: https://www.forexfactory.com/calendar?day=sep19.2017
# Completed scraping for sep08.2017, got 11 entries
# Saved 1262 entries to temporary file after 127 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep20.2017
# Completed scraping for sep11.2017, got 5 entries
# Saved 1267 entries to temporary file after 128 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep21.2017Completed scraping for sep10.2017, got 1 entries
#
# Scraping: https://www.forexfactory.com/calendar?day=sep22.2017
# Saved 1268 entries to temporary file after 129 dates
# Completed scraping for sep12.2017, got 10 entries
# Saved 1278 entries to temporary file after 130 dates
# Created backup at backup_130_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=sep23.2017
# Completed scraping for sep13.2017, got 18 entries
# Saved 1296 entries to temporary file after 131 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep24.2017Completed scraping for sep17.2017, got 4 entries
#
# Saved 1300 entries to temporary file after 132 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep25.2017
# Completed scraping for sep16.2017, got 1 entries
# Saved 1301 entries to temporary file after 133 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep26.2017
# Completed scraping for sep14.2017, got 8 entries
# Saved 1309 entries to temporary file after 134 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep27.2017
# Completed scraping for sep15.2017, got 10 entries
# Saved 1319 entries to temporary file after 135 dates
# Created backup at backup_135_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=sep28.2017
# Completed scraping for sep18.2017, got 11 entries
# Saved 1330 entries to temporary file after 136 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep29.2017
# Completed scraping for sep19.2017, got 10 entries
# Saved 1340 entries to temporary file after 137 dates
# Scraping: https://www.forexfactory.com/calendar?day=sep30.2017
# Completed scraping for sep20.2017, got 13 entries
# Saved 1353 entries to temporary file after 138 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct01.2017Completed scraping for sep23.2017, got 1 entries
#
# Saved 1354 entries to temporary file after 139 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct02.2017
# Completed scraping for sep24.2017, got 2 entries
# Scraping: https://www.forexfactory.com/calendar?day=oct03.2017
# Saved 1356 entries to temporary file after 140 dates
# Created backup at backup_140_forexfactory_calendar_full.csv
# Completed scraping for sep21.2017, got 14 entries
# Scraping: https://www.forexfactory.com/calendar?day=oct04.2017
# Saved 1370 entries to temporary file after 141 dates
# Completed scraping for sep22.2017, got 12 entries
# Saved 1382 entries to temporary file after 142 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct05.2017
# Completed scraping for sep25.2017, got 11 entries
# Saved 1393 entries to temporary file after 143 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct06.2017
# Completed scraping for sep26.2017, got 8 entries
# Saved 1401 entries to temporary file after 144 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct07.2017
# Completed scraping for sep27.2017, got 10 entries
# Saved 1411 entries to temporary file after 145 dates
# Created backup at backup_145_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=oct08.2017Completed scraping for sep29.2017, got 13 entries
#
# Saved 1424 entries to temporary file after 146 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct09.2017
# Completed scraping for sep28.2017, got 16 entries
# Saved 1440 entries to temporary file after 147 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct10.2017Completed scraping for sep30.2017, got 1 entries
#
# Saved 1441 entries to temporary file after 148 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct11.2017
# Completed scraping for oct01.2017, got 7 entries
# Saved 1448 entries to temporary file after 149 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct12.2017
# Completed scraping for oct03.2017, got 16 entries
# Saved 1464 entries to temporary file after 150 dates
# Created backup at backup_150_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=oct13.2017
# Completed scraping for oct04.2017, got 16 entries
# Saved 1480 entries to temporary file after 151 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct14.2017
# Completed scraping for oct02.2017, got 19 entries
# Saved 1499 entries to temporary file after 152 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct15.2017Completed scraping for oct06.2017, got 12 entries
#
# Saved 1511 entries to temporary file after 153 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct16.2017
# Scraping: https://www.forexfactory.com/calendar?day=oct17.2017
# Completed scraping for oct05.2017, got 16 entries
# Saved 1527 entries to temporary file after 154 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct18.2017
# Completed scraping for oct08.2017, got 2 entries
# Saved 1529 entries to temporary file after 155 dates
# Created backup at backup_155_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=oct19.2017
# Completed scraping for oct09.2017, got 9 entries
# Saved 1538 entries to temporary file after 156 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct20.2017
# Completed scraping for oct10.2017, got 17 entries
# Saved 1555 entries to temporary file after 157 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct21.2017
# Completed scraping for oct11.2017, got 10 entries
# Saved 1565 entries to temporary file after 158 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct22.2017
# Completed scraping for oct12.2017, got 14 entries
# Saved 1579 entries to temporary file after 159 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct23.2017
# Completed scraping for oct14.2017, got 2 entries
# Saved 1581 entries to temporary file after 160 dates
# Created backup at backup_160_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=oct24.2017
# Completed scraping for oct13.2017, got 10 entries
# Saved 1591 entries to temporary file after 161 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct25.2017
# Completed scraping for oct15.2017, got 6 entries
# Saved 1597 entries to temporary file after 162 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct26.2017
# Completed scraping for oct16.2017, got 7 entries
# Saved 1604 entries to temporary file after 163 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct27.2017
# Completed scraping for oct17.2017, got 16 entries
# Saved 1620 entries to temporary file after 164 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct28.2017
# Completed scraping for oct18.2017, got 11 entries
# Saved 1631 entries to temporary file after 165 dates
# Created backup at backup_165_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=oct29.2017
# Completed scraping for oct21.2017, got 1 entries
# Saved 1632 entries to temporary file after 166 dates
# Scraping: https://www.forexfactory.com/calendar?day=oct30.2017
# Completed scraping for oct20.2017, got 8 entries
# Scraping: https://www.forexfactory.com/calendar?day=oct31.2017
# Saved 1640 entries to temporary file after 167 dates
# Completed scraping for oct19.2017, got 10 entries
# Saved 1650 entries to temporary file after 168 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov01.2017
# Completed scraping for oct23.2017, got 5 entries
# Saved 1655 entries to temporary file after 169 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov02.2017
# Completed scraping for oct22.2017, got 3 entries
# Saved 1658 entries to temporary file after 170 dates
# Created backup at backup_170_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=nov03.2017Completed scraping for oct24.2017, got 9 entries
#
# Saved 1667 entries to temporary file after 171 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov04.2017
# Completed scraping for oct26.2017, got 11 entries
# Saved 1678 entries to temporary file after 172 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov05.2017
# Completed scraping for oct25.2017, got 12 entries
# Saved 1690 entries to temporary file after 173 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov06.2017Completed scraping for oct27.2017, got 3 entries
#
# Saved 1693 entries to temporary file after 174 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov07.2017
# Completed scraping for oct28.2017, got 1 entries
# Saved 1694 entries to temporary file after 175 dates
# Created backup at backup_175_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=nov08.2017
# Completed scraping for oct29.2017, got 1 entries
# Saved 1695 entries to temporary file after 176 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov09.2017
# Completed scraping for oct30.2017, got 14 entries
# Saved 1709 entries to temporary file after 177 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov10.2017
# Completed scraping for oct31.2017, got 17 entries
# Saved 1726 entries to temporary file after 178 dates
# Created hourly backup at hourly_backup_20250503_20_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=nov11.2017
# Completed scraping for nov02.2017, got 19 entries
# Saved 1745 entries to temporary file after 179 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov12.2017
# Completed scraping for nov03.2017, got 6 entries
# Saved 1751 entries to temporary file after 180 dates
# Created backup at backup_180_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=nov13.2017
# Scraping: https://www.forexfactory.com/calendar?day=nov14.2017
# Completed scraping for nov01.2017, got 18 entries
# Saved 1769 entries to temporary file after 181 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov15.2017Completed scraping for nov05.2017, got 6 entries
#
# Saved 1775 entries to temporary file after 182 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov16.2017
# Completed scraping for nov06.2017, got 16 entries
# Saved 1791 entries to temporary file after 183 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov17.2017
# Completed scraping for nov07.2017, got 16 entries
# Saved 1807 entries to temporary file after 184 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov18.2017Completed scraping for nov08.2017, got 13 entries
#
# Saved 1820 entries to temporary file after 185 dates
# Created backup at backup_185_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=nov19.2017
# Completed scraping for nov09.2017, got 13 entries
# Saved 1833 entries to temporary file after 186 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov20.2017
# Completed scraping for nov10.2017, got 5 entries
# Saved 1838 entries to temporary file after 187 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov21.2017
# Completed scraping for nov12.2017, got 4 entries
# Saved 1842 entries to temporary file after 188 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov22.2017
# Completed scraping for nov11.2017, got 1 entries
# Saved 1843 entries to temporary file after 189 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov23.2017
# Completed scraping for nov13.2017, got 9 entries
# Saved 1852 entries to temporary file after 190 dates
# Created backup at backup_190_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=nov24.2017
# Completed scraping for nov14.2017, got 14 entries
# Saved 1866 entries to temporary file after 191 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov25.2017
# Completed scraping for nov15.2017, got 15 entries
# Saved 1881 entries to temporary file after 192 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov26.2017Completed scraping for nov16.2017, got 18 entries
#
# Saved 1899 entries to temporary file after 193 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov27.2017
# Completed scraping for nov17.2017, got 6 entries
# Saved 1905 entries to temporary file after 194 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov28.2017
# Scraping: https://www.forexfactory.com/calendar?day=nov29.2017
# Completed scraping for nov19.2017, got 3 entries
# Saved 1908 entries to temporary file after 195 dates
# Created backup at backup_195_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=nov30.2017
# Completed scraping for nov20.2017, got 11 entries
# Saved 1919 entries to temporary file after 196 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec01.2017
# Completed scraping for nov22.2017, got 10 entries
# Saved 1929 entries to temporary file after 197 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec02.2017Completed scraping for nov21.2017, got 13 entries
#
# Saved 1942 entries to temporary file after 198 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec03.2017
# Completed scraping for nov23.2017, got 13 entries
# Saved 1955 entries to temporary file after 199 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec04.2017
# Scraping: https://www.forexfactory.com/calendar?day=dec05.2017
# Completed scraping for nov24.2017, got 4 entries
# Saved 1959 entries to temporary file after 200 dates
# Created backup at backup_200_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=dec06.2017
# Completed scraping for nov26.2017, got 1 entries
# Saved 1960 entries to temporary file after 201 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec07.2017
# Completed scraping for nov27.2017, got 4 entries
# Saved 1964 entries to temporary file after 202 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec08.2017
# Completed scraping for nov28.2017, got 19 entries
# Saved 1983 entries to temporary file after 203 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec09.2017Completed scraping for nov29.2017, got 21 entries
#
# Saved 2004 entries to temporary file after 204 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec10.2017
# Completed scraping for dec01.2017, got 15 entries
# Saved 2019 entries to temporary file after 205 dates
# Created backup at backup_205_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=dec11.2017
# Completed scraping for nov30.2017, got 20 entries
# Saved 2039 entries to temporary file after 206 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec12.2017
# Scraping: https://www.forexfactory.com/calendar?day=dec13.2017
# Completed scraping for dec03.2017, got 3 entries
# Saved 2042 entries to temporary file after 207 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec14.2017
# Completed scraping for dec04.2017, got 14 entries
# Saved 2056 entries to temporary file after 208 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec15.2017
# Completed scraping for dec06.2017, got 12 entries
# Saved 2068 entries to temporary file after 209 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec16.2017
# Completed scraping for dec05.2017, got 15 entries
# Saved 2083 entries to temporary file after 210 dates
# Created backup at backup_210_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=dec17.2017
# Completed scraping for dec07.2017, got 23 entries
# Saved 2106 entries to temporary file after 211 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec18.2017
# Completed scraping for dec08.2017, got 10 entries
# Saved 2116 entries to temporary file after 212 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec19.2017
# Completed scraping for dec11.2017, got 7 entries
# Saved 2123 entries to temporary file after 213 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec20.2017
# Completed scraping for dec10.2017, got 2 entries
# Saved 2125 entries to temporary file after 214 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec21.2017
# Scraping: https://www.forexfactory.com/calendar?day=dec22.2017
# Completed scraping for dec12.2017, got 13 entries
# Saved 2138 entries to temporary file after 215 dates
# Created backup at backup_215_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=dec23.2017
# Scraping: https://www.forexfactory.com/calendar?day=dec24.2017
# Completed scraping for dec15.2017, got 6 entries
# Saved 2144 entries to temporary file after 216 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec25.2017
# Completed scraping for dec14.2017, got 17 entries
# Saved 2161 entries to temporary file after 217 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec26.2017
# Completed scraping for dec13.2017, got 16 entries
# Saved 2177 entries to temporary file after 218 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec27.2017
# Completed scraping for dec17.2017, got 4 entries
# Saved 2181 entries to temporary file after 219 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec28.2017
# Completed scraping for dec18.2017, got 8 entries
# Saved 2189 entries to temporary file after 220 dates
# Created backup at backup_220_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=dec29.2017
# Completed scraping for dec21.2017, got 10 entries
# Saved 2199 entries to temporary file after 221 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec30.2017
# Completed scraping for dec19.2017, got 11 entries
# Saved 2210 entries to temporary file after 222 dates
# Scraping: https://www.forexfactory.com/calendar?day=dec31.2017
# Completed scraping for dec20.2017, got 13 entries
# Saved 2223 entries to temporary file after 223 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan01.2018
# Completed scraping for dec22.2017, got 6 entries
# Saved 2229 entries to temporary file after 224 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan02.2018
# Scraping: https://www.forexfactory.com/calendar?day=jan03.2018
# Completed scraping for dec25.2017, got 12 entries
# Saved 2241 entries to temporary file after 225 dates
# Created backup at backup_225_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=jan04.2018
# Completed scraping for dec26.2017, got 7 entries
# Saved 2248 entries to temporary file after 226 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan05.2018
# Completed scraping for dec24.2017, got 2 entries
# Saved 2250 entries to temporary file after 227 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan06.2018
# Completed scraping for dec27.2017, got 6 entries
# Saved 2256 entries to temporary file after 228 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan07.2018
# Completed scraping for dec30.2017, got 1 entries
# Saved 2257 entries to temporary file after 229 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan08.2018
# Completed scraping for dec29.2017, got 3 entries
# Saved 2260 entries to temporary file after 230 dates
# Created backup at backup_230_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=jan09.2018
# Completed scraping for jan01.2018, got 11 entries
# Saved 2271 entries to temporary file after 231 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan10.2018
# Completed scraping for dec28.2017, got 9 entries
# Saved 2280 entries to temporary file after 232 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan11.2018
# Completed scraping for dec31.2017, got 4 entries
# Saved 2284 entries to temporary file after 233 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan12.2018
# Completed scraping for jan02.2018, got 13 entries
# Saved 2297 entries to temporary file after 234 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan13.2018
# Completed scraping for jan06.2018, got 1 entries
# Saved 2298 entries to temporary file after 235 dates
# Created backup at backup_235_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=jan14.2018
# Completed scraping for jan03.2018, got 12 entries
# Saved 2310 entries to temporary file after 236 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan15.2018
# Completed scraping for jan04.2018, got 18 entries
# Saved 2328 entries to temporary file after 237 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan16.2018
# Completed scraping for jan05.2018, got 7 entries
# Saved 2335 entries to temporary file after 238 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan17.2018
# Completed scraping for jan07.2018, got 3 entries
# Saved 2338 entries to temporary file after 239 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan18.2018
# Completed scraping for jan10.2018, got 9 entries
# Saved 2347 entries to temporary file after 240 dates
# Created backup at backup_240_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=jan19.2018
# Completed scraping for jan08.2018, got 12 entries
# Scraping: https://www.forexfactory.com/calendar?day=jan20.2018
# Saved 2359 entries to temporary file after 241 dates
# Completed scraping for jan11.2018, got 14 entries
# Saved 2373 entries to temporary file after 242 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan21.2018
# Completed scraping for jan09.2018, got 15 entries
# Saved 2388 entries to temporary file after 243 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan22.2018
# Completed scraping for jan12.2018, got 8 entries
# Saved 2396 entries to temporary file after 244 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan23.2018
# Scraping: https://www.forexfactory.com/calendar?day=jan24.2018
# Completed scraping for jan15.2018, got 8 entries
# Saved 2404 entries to temporary file after 245 dates
# Created backup at backup_245_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=jan25.2018
# Completed scraping for jan14.2018, got 4 entries
# Saved 2408 entries to temporary file after 246 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan26.2018
# Completed scraping for jan16.2018, got 13 entries
# Saved 2421 entries to temporary file after 247 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan27.2018
# Scraping: https://www.forexfactory.com/calendar?day=jan28.2018
# Completed scraping for jan18.2018, got 7 entries
# Saved 2428 entries to temporary file after 248 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan29.2018
# Completed scraping for jan21.2018, got 1 entries
# Saved 2429 entries to temporary file after 249 dates
# Scraping: https://www.forexfactory.com/calendar?day=jan30.2018
# Completed scraping for jan17.2018, got 15 entries
# Saved 2444 entries to temporary file after 250 dates
# Created backup at backup_250_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=jan31.2018
# Completed scraping for jan19.2018, got 9 entries
# Saved 2453 entries to temporary file after 251 dates
# Scraping: https://www.forexfactory.com/calendar?day=feb01.2018
# Completed scraping for jan23.2018, got 13 entries
# Saved 2466 entries to temporary file after 252 dates
# Scraping: https://www.forexfactory.com/calendar?day=feb02.2018
# Completed scraping for jan22.2018, got 6 entries
# Saved 2472 entries to temporary file after 253 dates
# Scraping: https://www.forexfactory.com/calendar?day=feb03.2018
# Completed scraping for jan24.2018, got 10 entries
# Saved 2482 entries to temporary file after 254 dates
# Scraping: https://www.forexfactory.com/calendar?day=feb04.2018
# Completed scraping for jan26.2018, got 7 entries
# Saved 2489 entries to temporary file after 255 dates
# Created backup at backup_255_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=feb05.2018Completed scraping for jan25.2018, got 14 entries
#
# Saved 2503 entries to temporary file after 256 dates
# Scraping: https://www.forexfactory.com/calendar?day=feb06.2018
# Scraping: https://www.forexfactory.com/calendar?day=feb07.2018
# ...
# Saved 4995 entries to temporary file after 503 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov11.2018Completed scraping for nov01.2018, got 19 entries
#
# Saved 5014 entries to temporary file after 504 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov12.2018
# Scraping: https://www.forexfactory.com/calendar?day=nov13.2018
# Completed scraping for nov02.2018, got 10 entries
# Saved 5024 entries to temporary file after 505 dates
# Created backup at backup_505_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=nov14.2018
# Completed scraping for nov04.2018, got 7 entries
# Saved 5031 entries to temporary file after 506 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov15.2018
# Completed scraping for nov05.2018, got 8 entries
# Saved 5039 entries to temporary file after 507 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov16.2018Completed scraping for nov06.2018, got 17 entries
#
# Saved 5056 entries to temporary file after 508 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov17.2018
# Completed scraping for nov07.2018, got 16 entries
# Saved 5072 entries to temporary file after 509 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov18.2018
# Completed scraping for nov08.2018, got 16 entries
# Scraping: https://www.forexfactory.com/calendar?day=nov19.2018
# Saved 5088 entries to temporary file after 510 dates
# Created backup at backup_510_forexfactory_calendar_full.csv
# Scraping: https://www.forexfactory.com/calendar?day=nov20.2018
# Completed scraping for nov11.2018, got 1 entries
# Saved 5089 entries to temporary file after 511 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov21.2018
# Completed scraping for nov09.2018, got 6 entries
# Saved 5095 entries to temporary file after 512 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov22.2018
# Completed scraping for nov12.2018, got 8 entries
# Saved 5103 entries to temporary file after 513 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov23.2018
# Error occurred. Created emergency backup at error_backup_20250503_211059_forexfactory_calendar_full.csv
# Error scraping nov13.2018: HTTPConnectionPool(host='localhost', port=51199): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=nov24.2018
# Error occurred. Created emergency backup at error_backup_20250503_211107_forexfactory_calendar_full.csv
# Error scraping nov14.2018: HTTPConnectionPool(host='localhost', port=55603): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=nov25.2018
# Scraping: https://www.forexfactory.com/calendar?day=nov26.2018
# Error occurred. Created emergency backup at error_backup_20250503_211118_forexfactory_calendar_full.csv
# Error scraping nov15.2018: HTTPConnectionPool(host='localhost', port=57335): Read timed out. (read timeout=120)
# Completed scraping for nov16.2018, got 10 entries
# Saved 5113 entries to temporary file after 514 dates
# Scraping: https://www.forexfactory.com/calendar?day=nov27.2018
# Scraping: https://www.forexfactory.com/calendar?day=nov28.2018
# Scraping: https://www.forexfactory.com/calendar?day=nov29.2018
# Error occurred. Created emergency backup at error_backup_20250503_211211_forexfactory_calendar_full.csv
# Error scraping nov18.2018: HTTPConnectionPool(host='localhost', port=50683): Read timed out. (read timeout=120)
# Error occurred. Created emergency backup at error_backup_20250503_211213_forexfactory_calendar_full.csv
# Error scraping nov19.2018: HTTPConnectionPool(host='localhost', port=49339): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=nov30.2018
# Scraping: https://www.forexfactory.com/calendar?day=dec01.2018
# Error occurred. Created emergency backup at error_backup_20250503_211230_forexfactory_calendar_full.csv
# Error scraping nov20.2018: HTTPConnectionPool(host='localhost', port=36831): Read timed out. (read timeout=120)
# Error occurred. Created emergency backup at error_backup_20250503_211232_forexfactory_calendar_full.csv
# Error scraping nov21.2018: HTTPConnectionPool(host='localhost', port=42963): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec02.2018
# Error occurred. Created emergency backup at error_backup_20250503_211248_forexfactory_calendar_full.csv
# Error scraping nov22.2018: HTTPConnectionPool(host='localhost', port=46771): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec03.2018
# Error occurred. Created emergency backup at error_backup_20250503_211306_forexfactory_calendar_full.csv
# Error scraping nov23.2018: HTTPConnectionPool(host='localhost', port=48211): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec04.2018
# Error occurred. Created emergency backup at error_backup_20250503_211323_forexfactory_calendar_full.csv
# Error scraping nov24.2018: HTTPConnectionPool(host='localhost', port=45357): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec05.2018
# Error occurred. Created emergency backup at error_backup_20250503_211331_forexfactory_calendar_full.csv
# Error scraping nov25.2018: HTTPConnectionPool(host='localhost', port=60487): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec06.2018
# Scraping: https://www.forexfactory.com/calendar?day=dec07.2018
# Error occurred. Created emergency backup at error_backup_20250503_211333_forexfactory_calendar_full.csv
# Error scraping nov26.2018: HTTPConnectionPool(host='localhost', port=38629): Read timed out. (read timeout=120)
# Error occurred. Created emergency backup at error_backup_20250503_211334_forexfactory_calendar_full.csv
# Error scraping nov27.2018: HTTPConnectionPool(host='localhost', port=40207): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec08.2018
# Error occurred. Created emergency backup at error_backup_20250503_211423_forexfactory_calendar_full.csv
# Error scraping nov28.2018: HTTPConnectionPool(host='localhost', port=46307): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec09.2018
# Error occurred. Created emergency backup at error_backup_20250503_211428_forexfactory_calendar_full.csv
# Error scraping nov29.2018: HTTPConnectionPool(host='localhost', port=38589): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec10.2018
# Scraping: https://www.forexfactory.com/calendar?day=dec11.2018
# Error occurred. Created emergency backup at error_backup_20250503_211441_forexfactory_calendar_full.csv
# Error scraping nov30.2018: HTTPConnectionPool(host='localhost', port=37013): Read timed out. (read timeout=120)
# Error occurred. Created emergency backup at error_backup_20250503_211444_forexfactory_calendar_full.csv
# Error scraping dec01.2018: HTTPConnectionPool(host='localhost', port=46323): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec12.2018
# Error occurred. Created emergency backup at error_backup_20250503_211503_forexfactory_calendar_full.csv
# Error scraping dec02.2018: HTTPConnectionPool(host='localhost', port=48825): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec13.2018
# Error occurred. Created emergency backup at error_backup_20250503_211524_forexfactory_calendar_full.csv
# Error scraping dec03.2018: HTTPConnectionPool(host='localhost', port=32773): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec14.2018
# Error occurred. Created emergency backup at error_backup_20250503_211536_forexfactory_calendar_full.csv
# Error scraping dec04.2018: HTTPConnectionPool(host='localhost', port=47859): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec15.2018
# Scraping: https://www.forexfactory.com/calendar?day=dec16.2018
# Error occurred. Created emergency backup at error_backup_20250503_211544_forexfactory_calendar_full.csv
# Error scraping dec05.2018: HTTPConnectionPool(host='localhost', port=43815): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec17.2018
# Error occurred. Created emergency backup at error_backup_20250503_211549_forexfactory_calendar_full.csv
# Error scraping dec06.2018: HTTPConnectionPool(host='localhost', port=47251): Read timed out. (read timeout=120)
# Error occurred. Created emergency backup at error_backup_20250503_211553_forexfactory_calendar_full.csv
# Error scraping dec07.2018: HTTPConnectionPool(host='localhost', port=45987): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec18.2018
# Scraping: https://www.forexfactory.com/calendar?day=dec19.2018
# Error occurred. Created emergency backup at error_backup_20250503_211640_forexfactory_calendar_full.csv
# Error scraping dec08.2018: HTTPConnectionPool(host='localhost', port=41579): Read timed out. (read timeout=120)
# Error occurred. Created emergency backup at error_backup_20250503_211645_forexfactory_calendar_full.csv
# Error scraping dec09.2018: HTTPConnectionPool(host='localhost', port=33909): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec20.2018
# Scraping: https://www.forexfactory.com/calendar?day=dec21.2018
# Error occurred. Created emergency backup at error_backup_20250503_211654_forexfactory_calendar_full.csv
# Error scraping dec10.2018: HTTPConnectionPool(host='localhost', port=54615): Read timed out. (read timeout=120)
# Error occurred. Created emergency backup at error_backup_20250503_211659_forexfactory_calendar_full.csv
# Error scraping dec11.2018: HTTPConnectionPool(host='localhost', port=34187): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec22.2018
# Error occurred. Created emergency backup at error_backup_20250503_211725_forexfactory_calendar_full.csv
# Error scraping dec12.2018: HTTPConnectionPool(host='localhost', port=39205): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec23.2018
# Error occurred. Created emergency backup at error_backup_20250503_211749_forexfactory_calendar_full.csv
# Error scraping dec13.2018: HTTPConnectionPool(host='localhost', port=34311): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec24.2018
# Scraping: https://www.forexfactory.com/calendar?day=dec25.2018
# Error occurred. Created emergency backup at error_backup_20250503_211802_forexfactory_calendar_full.csv
# Error scraping dec14.2018: HTTPConnectionPool(host='localhost', port=59215): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec26.2018
# Error occurred. Created emergency backup at error_backup_20250503_211809_forexfactory_calendar_full.csv
# Error scraping dec15.2018: HTTPConnectionPool(host='localhost', port=54087): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec27.2018
# Error occurred. Created emergency backup at error_backup_20250503_211815_forexfactory_calendar_full.csv
# Error scraping dec16.2018: HTTPConnectionPool(host='localhost', port=39649): Read timed out. (read timeout=120)
# Error occurred. Created emergency backup at error_backup_20250503_211821_forexfactory_calendar_full.csv
# Error scraping dec17.2018: HTTPConnectionPool(host='localhost', port=38631): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec28.2018
# Scraping: https://www.forexfactory.com/calendar?day=dec29.2018
# Error occurred. Created emergency backup at error_backup_20250503_211910_forexfactory_calendar_full.csv
# Error scraping dec18.2018: HTTPConnectionPool(host='localhost', port=56081): Read timed out. (read timeout=120)
# Error occurred. Created emergency backup at error_backup_20250503_211916_forexfactory_calendar_full.csv
# Error scraping dec19.2018: HTTPConnectionPool(host='localhost', port=47949): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=dec30.2018
# Scraping: https://www.forexfactory.com/calendar?day=dec31.2018
# Error occurred. Created emergency backup at error_backup_20250503_211928_forexfactory_calendar_full.csv
# Error scraping dec20.2018: HTTPConnectionPool(host='localhost', port=40457): Read timed out. (read timeout=120)
# Error occurred. Created emergency backup at error_backup_20250503_211936_forexfactory_calendar_full.csv
# Error scraping dec21.2018: HTTPConnectionPool(host='localhost', port=34027): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=jan01.2019
# Error occurred. Created emergency backup at error_backup_20250503_212003_forexfactory_calendar_full.csv
# Error scraping dec22.2018: HTTPConnectionPool(host='localhost', port=57219): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=jan02.2019
# Scraping: https://www.forexfactory.com/calendar?day=jan03.2019
# Error occurred. Created emergency backup at error_backup_20250503_212035_forexfactory_calendar_full.csv
# Error scraping dec23.2018: HTTPConnectionPool(host='localhost', port=47159): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=jan04.2019
# Error occurred. Created emergency backup at error_backup_20250503_212048_forexfactory_calendar_full.csv
# Error scraping dec24.2018: HTTPConnectionPool(host='localhost', port=53159): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=jan05.2019
# Scraping: https://www.forexfactory.com/calendar?day=jan06.2019
# Error occurred. Created emergency backup at error_backup_20250503_212054_forexfactory_calendar_full.csv
# Error scraping dec25.2018: HTTPConnectionPool(host='localhost', port=60915): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=jan07.2019
# Error occurred. Created emergency backup at error_backup_20250503_212112_forexfactory_calendar_full.csv
# Error scraping dec26.2018: HTTPConnectionPool(host='localhost', port=52813): Read timed out. (read timeout=120)
# Error occurred. Created emergency backup at error_backup_20250503_212120_forexfactory_calendar_full.csv
# Error scraping dec27.2018: HTTPConnectionPool(host='localhost', port=58277): Read timed out. (read timeout=120)
# Scraping: https://www.forexfactory.com/calendar?day=jan08.2019
# Scraping: https://www.forexfactory.com/calendar?day=jan09.2019
# Error occurred. Created emergency backup at error_backup_20250503_212153_forexfactory_calendar_full.csv
# Error scraping jan01.2019: Message: session not created: DevToolsActivePort file doesn't exist
# Stacktrace:
# #0 0x5b30345037fa <unknown>
# #1 0x5b3033fa7e90 <unknown>
# #2 0x5b3033fe6ff8 <unknown>
# #3 0x5b3033fe268e <unknown>
# #4 0x5b3033fdda3f <unknown>
# #5 0x5b303402dc15 <unknown>
# #6 0x5b303402d136 <unknown>
# #7 0x5b303401f013 <unknown>
# #8 0x5b3033febb3b <unknown>
# #9 0x5b3033fec7a1 <unknown>
# #10 0x5b30344c8b9b <unknown>
# #11 0x5b30344cca8a <unknown>
# #12 0x5b30344b0912 <unknown>
# #13 0x5b30344cd604 <unknown>
# #14 0x5b303449574f <unknown>
# #15 0x5b30344f1678 <unknown>
# #16 0x5b30344f1856 <unknown>
# #17 0x5b3034502666 <unknown>
# #18 0x7931c9fddac3 <unknown>
#
# Scraping: https://www.forexfactory.com/calendar?day=jan10.2019
# Scraping: https://www.forexfactory.com/calendar?day=jan11.2019
# Scraping: https://www.forexfactory.com/calendar?day=jan12.2019
# Scraping: https://www.forexfactory.com/calendar?day=jan13.2019
# Scraping: https://www.forexfactory.com/calendar?day=jan14.2019
# Scraping: https://www.forexfactory.com/calendar?day=jan15.2019
# Scraping: https://www.forexfactory.com/calendar?day=jan16.2019
# Error occurred. Created emergency backup at error_backup_20250503_212217_forexfactory_calendar_full.csv
# Error scraping dec29.2018: HTTPConnectionPool(host='localhost', port=52729): Read timed out. (read timeout=120)
# Error occurred. Created emergency backup at error_backup_20250503_212254_forexfactory_calendar_full.csv
# Error scraping dec28.2018: HTTPConnectionPool(host='localhost', port=41121): Read timed out. (read timeout=120)

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.32.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (2.4.0)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.11/dist-packages (from selenium) (2025.4.26)
# Requirement already satisfied: typing_extensions~=4.9 in /usr/local/lib/python3.11/dist-packages (from selenium) (4.13.2)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/lib/python3.11/dist-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (3.10)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.16.0)
# Downloading selenium-4.32.0-py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 49.9 MB/s eta 0:00:00
# Downloading trio-0.30.0-py3-none-any.whl (499 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.2/499.2 kB 23.2 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, outcome, trio, trio-websocket, selenium
# Successfully installed outcome-1.3.0.post0 selenium-4.32.0 trio-0.30.0 trio-websocket-0.12.2 wsproto-1.2.0
